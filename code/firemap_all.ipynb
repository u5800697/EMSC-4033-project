# %% [markdown]
# # PROJECT FOR YEARLY FIRE SPREAD THROUGHT THE COUNTRY
#
# below is code to get a map of yearly spread, go to the bottom for inpuit box
#
#  - Part 1 shows the overall spread of fire over 100 years
#  - Part 2 is code used to get the yearly fire spread
#  - Part 3 contains input methods for fire spread and drought/rainfall anomoly data

# %% [markdown]
# _______
# ## Part 1: 100 years of bushfires in Australia
# ______

# %%
import folium
import geopandas as gpd
from folium import IFrame
import os
import base64
from folium import plugins
from PIL import Image

# %%
#now lets do this for the given data
map_fires_NSW = folium.Map(location=[-33.2532 , 149.9211],tiles ='https://{s}.tile.openstreetmap.fr/hot/{z}/{x}/{y}.png', zoom_start=6, attr = 'my attirbution')
NSW_fire_polys = os.path.join("NSW_fire_history_polygons.geojson") #need to test
g = folium.GeoJson(NSW_fire_polys, name = 'NSW_fire_polys').add_to(map_fires_NSW) 
map_fires_NSW

# %%
gdf = gpd.read_file('NSW_fire_history_polygons.geojson').iloc[0:15000]

fmap= folium.Map(location=[-33.2532 , 149.9211], tiles='https://{s}.tile.openstreetmap.fr/hot/{z}/{x}/{y}.png', zoom_start=6, attr = 'my attirbution', control_scale=True)

folium.GeoJson(
        gdf[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
        name='NSW_fires',
        show=True,  
        highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
        tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
        ),  
).add_to(fmap)

display(fmap)

# %% [markdown]
# ______
# ## Part 2: Code
# _______

# %%
#set our data in
sixtyeight_fires = gpd.read_file('1968.geojson').iloc[0:3000]
sixtynine_fires = gpd.read_file('1969.geojson').iloc[0:3000]
thirtyfive =  gpd.read_file('1935.geojson').iloc[0:3000]
thirtyseven =  gpd.read_file('1937.geojson').iloc[0:3000]
thirtyeight=gpd.read_file('1938.geojson').iloc[0:3000]
thirtynine=gpd.read_file('1939.geojson').iloc[0:3000]
fourtyone=gpd.read_file('1941.geojson').iloc[0:3000]
fourtytwo=gpd.read_file('1942.geojson').iloc[0:3000]
fourtythree=gpd.read_file('1943.geojson').iloc[0:3000]
fourtyfour=gpd.read_file('1944.geojson').iloc[0:3000]
fourtyfive=gpd.read_file('1945.geojson').iloc[0:3000]
fourtysix=gpd.read_file('1946.geojson').iloc[0:3000]
fourtyseven=gpd.read_file('1947.geojson').iloc[0:3000]
fourtyeight=gpd.read_file('1948.geojson').iloc[0:3000]
fourtynine=gpd.read_file('1949.geojson').iloc[0:3000]
fifty=gpd.read_file('1950.geojson').iloc[0:3000]
fiftyone=gpd.read_file('1951.geojson').iloc[0:3000]
fiftytwo=gpd.read_file('1952.geojson').iloc[0:3000]
fiftythree=gpd.read_file('1953.geojson').iloc[0:3000]
fiftyfour=gpd.read_file('1954.geojson').iloc[0:3000]
fiftyfive=gpd.read_file('1955.geojson').iloc[0:3000]
fiftysix=gpd.read_file('1956.geojson').iloc[0:3000]
fiftyseven=gpd.read_file('1957.geojson').iloc[0:3000]
fiftyeight=gpd.read_file('1958.geojson').iloc[0:3000]
fiftynine= gpd.read_file('1959.geojson').iloc[0:3000]
sixty=gpd.read_file('1960.geojson').iloc[0:3000]
sixtyone=gpd.read_file('1961.geojson').iloc[0:3000]
sixtytwo=gpd.read_file('1962.geojson').iloc[0:3000]
sixtythree=gpd.read_file('1963.geojson').iloc[0:3000]
sixtyfour=gpd.read_file('1964.geojson').iloc[0:3000]
sixtyfive=gpd.read_file('1965.geojson').iloc[0:3000]
sixtysix=gpd.read_file('1966.geojson').iloc[0:3000]
sixtyseven =gpd.read_file('1967.geojson').iloc[0:3000]
seventy_fires = gpd.read_file('1970.geojson').iloc[0:3000]
seventyone_fires = gpd.read_file('1971.geojson').iloc[0:3000]
seventytwo_fires =gpd.read_file('1972.geojson').iloc[0:3000]
seventythree_fires =gpd.read_file('1973.geojson').iloc[0:3000]
seventyfour_fires =gpd.read_file('1974.geojson').iloc[0:3000]
seventyfive_fires =gpd.read_file('1975.geojson').iloc[0:3000]
seventysix_fires =gpd.read_file('1976.geojson').iloc[0:3000]
seventyseven_fires =gpd.read_file('1977.geojson').iloc[0:3000]
seventyeight_fires =gpd.read_file('1978.geojson').iloc[0:3000]
seventynine_fires =gpd.read_file('1979.geojson').iloc[0:3000]
eighty_fires =gpd.read_file('1980.geojson').iloc[0:3000]
eightyone_fires =gpd.read_file('1981.geojson').iloc[0:3000]
eightytwo_fires =gpd.read_file('1982.geojson').iloc[0:3000]
eightythree_fires = gpd.read_file('1983.geojson').iloc[0:3000]
eightyfour_fires =gpd.read_file('1984.geojson').iloc[0:3000]
eightyfive_fires =gpd.read_file('1985.geojson').iloc[0:3000]
eightysix_fires =gpd.read_file('1986.geojson').iloc[0:3000]
eightyseven_fires =gpd.read_file('1987.geojson').iloc[0:3000]
eightyeight_fires =gpd.read_file('1988.geojson').iloc[0:3000]
eightynine_fires =gpd.read_file('1989.geojson').iloc[0:3000]
ninety_fires = gpd.read_file('1990.geojson').iloc[0:3000]
ninetyone_fires =gpd.read_file('1991.geojson').iloc[0:3000]
ninetytwo_fires =gpd.read_file('1992.geojson').iloc[0:3000]
ninetythree_fires =gpd.read_file('1993.geojson').iloc[0:3000]
ninetyfour_fires =gpd.read_file('1994.geojson').iloc[0:3000]
ninetyfive_fires =gpd.read_file('1995.geojson').iloc[0:3000]
ninetysix_fires =gpd.read_file('1996.geojson').iloc[0:3000]
ninetyseven_fires =gpd.read_file('1997.geojson').iloc[0:3000]
ninetyeight_fires = gpd.read_file('1998.geojson').iloc[0:3000]
ninetynine_fires =gpd.read_file('1999.geojson').iloc[0:3000]
twothousand_fires =gpd.read_file('2000.geojson').iloc[0:3000]
thousandone_fires =gpd.read_file('2001.geojson').iloc[0:3000]
thousandtwo_fires =gpd.read_file('2002.geojson').iloc[0:3000]
thousandthree_fires =gpd.read_file('2003.geojson').iloc[0:3000]
thousandfour_fires =gpd.read_file('2004.geojson').iloc[0:3000]
thousandfive_fires = gpd.read_file('2005.geojson').iloc[0:3000]
thousandsix =gpd.read_file('2006.geojson').iloc[0:3000]
thousandseven =gpd.read_file('2007.geojson').iloc[0:3000]
thousandeight =gpd.read_file('2008.geojson').iloc[0:3000]
thousandnine =gpd.read_file('2009.geojson').iloc[0:3000]
ten =gpd.read_file('2010.geojson').iloc[0:3000]
eleven =gpd.read_file('2011.geojson').iloc[0:3000]
twelve =gpd.read_file('2012.geojson').iloc[0:3000]
thirteen =gpd.read_file('2013.geojson').iloc[0:3000]
fourteen =gpd.read_file('2014.geojson').iloc[0:3000]
fifteen =gpd.read_file('2015.geojson').iloc[0:3000]
sixteen =gpd.read_file('2016.geojson').iloc[0:3000]
seventeen =gpd.read_file('2017.geojson').iloc[0:3000]
eighteen =gpd.read_file('2018.geojson').iloc[0:3000]
nineteen =gpd.read_file('2019.geojson').iloc[0:3000]

# %%
#now make a function to show fires in a given year
def fireanddroughtdash(Year):
    print('fire rainfall and drought data, fire data from NSW government, fire and drought data from Bureau of Meteorology')
    nodatamap = folium.Map(location=[-33.2532 , 149.9211], tiles='https://{s}.tile.openstreetmap.fr/hot/{z}/{x}/{y}.png', zoom_start=7, attr = 'my attirbution', control_scale=True)
    iconerror = folium.features.CustomIcon('./nodata.png', icon_size=(600,200))
    popuperror = "<strong>error</strong>"
    folium.Marker([-33.2532 , 149.9211], tooltip="nodata", popup=popuperror, icon=iconerror).add_to(nodatamap)
    fmap= folium.Map(location=[-33.2532 , 149.9211], tiles='https://{s}.tile.openstreetmap.fr/hot/{z}/{x}/{y}.png', zoom_start=6, attr = 'my attirbution', control_scale=True)
    folium.plugins.Fullscreen().add_to(fmap)
    if Year == 1935:
        folium.GeoJson(
            thirtyfive[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1935.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1935.png")
        display(im2)
    if Year == 1936 or Year == 1940:
        nodatamap = folium.Map(location=[-33.2532 , 149.9211], tiles='https://{s}.tile.openstreetmap.fr/hot/{z}/{x}/{y}.png', zoom_start=7, attr = 'my attirbution', control_scale=True)
        iconerror = folium.features.CustomIcon('./nodata.png', icon_size=(600,200))
        popuperror = "<strong>error</strong>"
        folium.Marker([-33.2532 , 149.9211], tooltip="nodata", popup=popuperror, icon=iconerror).add_to(nodatamap)
        display(nodatamap)
    if Year == 1937:
        folium.GeoJson(
            thirtyseven[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1937.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1937.png")
        display(im2)
    if Year == 1938:
        folium.GeoJson(
            thirtyeight[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1938.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1938.png")
        display(im2)
    if Year == 1939:
        folium.GeoJson(
            thirtynine[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1939.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1939.png")
        display(im2)
    if Year == 1941:
        folium.GeoJson(
            fourtyone[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1941.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1941.png")
        display(im2)
    if Year == 1942:
        folium.GeoJson(
            fourtytwo[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1942.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1942.png")
        display(im2)
    if Year == 1943:
        folium.GeoJson(
            fourtythree[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1943.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1943.png")
        display(im2)

    if Year == 1944:
        folium.GeoJson(
            fourtyfour[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1944.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1944.png")
        display(im2)
    if Year == 1945:
        folium.GeoJson(
            fourtyfive[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1945.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1945.png")
        display(im2)
    if Year == 1946:
        folium.GeoJson(
            fourtysix[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1946.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1946.png")
        display(im2)
    if Year == 1947:
        folium.GeoJson(
            fourtyseven[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1947.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1947.png")
        display(im2)
    if Year == 1948:
        folium.GeoJson(
            fourtyeight[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1948.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1948.png")
        display(im2)
    if Year == 1949:
        folium.GeoJson(
            fourtynine[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1949.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1949.png")
        display(im2)
    if Year == 1950:
        folium.GeoJson(
            fifty[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1950.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1950.png")
        display(im2)
    if Year == 1951:
        folium.GeoJson(
            fiftyone[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1951.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1951.png")
        display(im2)
    if Year == 1952:
        folium.GeoJson(
            fiftytwo[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1952.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1952.png")
        display(im2)
    if Year == 1953:
        folium.GeoJson(
            fiftythree[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1953.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1953.png")
        display(im2)
    if Year == 1954:
        folium.GeoJson(
            fiftyfour[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1954.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1954.png")
        display(im2)
    if Year == 1955:
        folium.GeoJson(
            fiftyfive[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1955.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1955.png")
        display(im2)
    if Year == 1956:
        folium.GeoJson(
            fiftysix[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1956.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1956.png")
        display(im2)
    if Year == 1957:
        folium.GeoJson(
            fiftyseven[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1957.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1957.png")
        display(im2)
    if Year == 1958:
        folium.GeoJson(
            fiftyeight[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1958.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1958.png")
        display(im2)
    if Year == 1959:
        folium.GeoJson(
            fiftynine[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1959.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1959.png")
        display(im2)
    if Year == 1960:
        folium.GeoJson(
            sixty[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1960.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1960.png")
        display(im2)
    if Year == 1961:
        folium.GeoJson(
            sixtyone[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1961.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1961.png")
        display(im2)
    if Year == 1962:
        folium.GeoJson(
            sixtytwo[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1962.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1962.png")
        display(im2)
    if Year == 1963:
        folium.GeoJson(
            sixtythree[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1963.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1963.png")
        display(im2)
    if Year == 1964:
        folium.GeoJson(
            sixtyfour[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1964.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1964.png")
        display(im2)
    if Year == 1965:
        folium.GeoJson(
            sixtyfive[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1965.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1965.png")
        display(im2)
    if Year == 1966:
        folium.GeoJson(
            sixtysix[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1966.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1966.png")
        display(im2)
    if Year == 1967:
        folium.GeoJson(
            sixtyseven[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1967.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1967.png")
        display(im2)
    if Year == 1968:
        folium.GeoJson(
            sixtyeight_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1968.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1968.png")
        display(im2)
    if Year == 1969:
        folium.GeoJson(
            sixtynine_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1969.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1969.png")
        display(im2)
    if Year == 1970:
        folium.GeoJson(
            seventy_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1970.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1970.png")
        display(im2)
    if Year == 1971:
        folium.GeoJson(
            seventyone_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1971.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1971.png")
        display(im2)
    if Year == 1972:
        folium.GeoJson(
            seventytwo_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1972.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1972.png")
        display(im2)
    if Year == 1973:
        folium.GeoJson(
            seventythree_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1973.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1973.png")
        display(im2)
    if Year == 1974:
        folium.GeoJson(
            seventyfour_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1974.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1974.png")
        display(im2)
    if Year == 1975:
        folium.GeoJson(
            seventyfive_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1975.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1975.png")
        display(im2)
    if Year == 1976:
        folium.GeoJson(
            seventysix_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1976.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1976.png")
        display(im2)
    if Year == 1977:
        folium.GeoJson(
            seventyseven_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1977.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1977.png")
        display(im2)
    if Year == 1978:
        folium.GeoJson(
            seventyeight_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1978.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1978.png")
        display(im2)
    if Year == 1979:
        folium.GeoJson(
            seventynine_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1979.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1979.png")
        display(im2)
    if Year == 1980:
        folium.GeoJson(
            eighty_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1980.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1980.png")
        display(im2)
    if Year == 1981:
        folium.GeoJson(
            eightyone_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1981.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1981.png")
        display(im2)
    if Year == 1982:
        folium.GeoJson(
            eightytwo_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1982.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1982.png")
        display(im2)
    if Year == 1983:
        folium.GeoJson(
            eightythree_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        im = Image.open("./bomdata/drought/1983.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1983.png")
        display(im2)
    if Year == 1984:
        folium.GeoJson(
            eightyfour_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1984.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1984.png")
        display(im2)
    if Year == 1985:
        folium.GeoJson(
            eightyfive_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1985.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1985.png")
        display(im2)
    if Year == 1986:
        folium.GeoJson(
            eightysix_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1986.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1986.png")
        display(im2)
    if Year == 1987:
        folium.GeoJson(
            eightyseven_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1987.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1987.png")
        display(im2)
    if Year == 1988:
        folium.GeoJson(
            eightyeight_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1988.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1988.png")
        display(im2)
    if Year == 1989:
        folium.GeoJson(
            eightynine_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1989.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1989.png")
        display(im2)
    if Year == 1990:
        folium.GeoJson(
            ninety_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1990.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1990.png")
        display(im2)
    if Year == 1991:
        folium.GeoJson(
            ninetyone_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1991.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1991.png")
        display(im2)
    if Year == 1992:
        folium.GeoJson(
            ninetytwo_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1992.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1992.png")
        display(im2)
    if Year == 1993:
        folium.GeoJson(
            ninetythree_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1993.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1993.png")
        display(im2)
    if Year == 1994:
        folium.GeoJson(
            ninetyfour_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1994.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1994.png")
        display(im2)
    if Year == 1995:
        folium.GeoJson(
            ninetyfive_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1995.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1995.png")
        display(im2)
    if Year == 1996:
        folium.GeoJson(
            ninetysix_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1996.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1996.png")
        display(im2)
    if Year == 1997:
        folium.GeoJson(
            ninetyseven_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1997.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1997.png")
        display(im2)
    if Year == 1998:
        folium.GeoJson(
            ninetyeight_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1998.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1998.png")
        display(im2)
    if Year == 1999:
        folium.GeoJson(
            ninetynine_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/1999.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/1999.png")
        display(im2)
    if Year == 2000:
        folium.GeoJson(
            twothousand_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/2000.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/2000.png")
        display(im2)
    if Year == 2001:
        folium.GeoJson(
            thousandone_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/2001.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/2001.png")
        display(im2)
    if Year == 2002:
        folium.GeoJson(
            thousandtwo_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/2002.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/2002.png")
        display(im2)
    if Year == 2003:
        folium.GeoJson(
            thousandthree_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/2003.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/2003.png")
        display(im2)
    if Year == 2004:
        folium.GeoJson(
            thousandfour_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/2004.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/2004.png")
        display(im2)
    if Year == 2005:
        folium.GeoJson(
            thousandfive_fires[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/2005.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/2005.png")
        display(im2)
    if Year == 2006:
        folium.GeoJson(
            thousandsix[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/2006.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/2006.png")
        display(im2)
    if Year == 2007:
        folium.GeoJson(
            thousandseven[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/2007.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/2007.png")
        display(im2)
    if Year == 2008:
        folium.GeoJson(
            thousandeight[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/2008.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/2008.png")
        display(im2)
    if Year == 2009:
        folium.GeoJson(
            thousandnine[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/2009.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/2009.png")
        display(im2)
    if Year == 2010:
        folium.GeoJson(
            ten[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/2010.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/2010.png")
        display(im2)
    if Year == 2011:
        folium.GeoJson(
            eleven[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/2011.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/2011.png")
        display(im2)
    if Year == 2012:
        folium.GeoJson(
            twelve[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/2012.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/2012.png")
        display(im2)
    if Year == 2013:
        folium.GeoJson(
            thirteen[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/2013.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/2013.png")
        display(im2)
    if Year == 2014:
        folium.GeoJson(
            fourteen[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/2014.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/2014.png")
        display(im2)
    if Year == 2015:
        folium.GeoJson(
            fifteen[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/2015.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/2015.png")
        display(im2)
    if Year == 2016:
        folium.GeoJson(
            sixteen[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/2016.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/2016.png")
        display(im2)
    if Year == 2017:
        folium.GeoJson(
            seventeen[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/2017.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/2017.png")
        display(im2)
    if Year == 2018:
        folium.GeoJson(
            eighteen[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/2018.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/2018.png")
        display(im2)
    if Year == 2019:
        folium.GeoJson(
            nineteen[['FireName','Label','Type', "AreaHa", "Year",'geometry']].to_json(), 
            name='NSW_fires',
            show=True,  
            highlight_function=lambda x: {'weight':3, 
                                      'color':'red',
                                      'fillOpacity':1},    
            tooltip=folium.features.GeoJsonTooltip(
            fields=['FireName','Label','Type',"AreaHa","Year"],
            aliases=['FireName:','Label:','Type:',"Hactares burned","Year"],                              
            ),  
        ).add_to(fmap)
        display(fmap)
        print('Bureau of Meteorology data')
        im = Image.open("./bomdata/drought/2019.png")
        display(im)
        im2 = Image.open("./bomdata/rainfall anomoly/2019.png")
        display(im2)
    if Year <= 1934 or Year >=2020:
        iconerror = folium.features.CustomIcon('./errortext.png', icon_size=(600,200))
        popuperror = "<strong>error</strong>"
        folium.Marker([-33.2532 , 149.9211], tooltip="error", popup=popuperror, icon=iconerror).add_to(fmap)
        display(fmap)

# %% [markdown]
# ________
# ## Part 3: Input
# ________

# %%
fireanddroughtdash(float(input('please enter a year:')))
